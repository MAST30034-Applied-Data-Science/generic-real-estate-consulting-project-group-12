# %%
import geopandas as gpd
bus_sf = gpd.read_file("../data/raw/PUBLIC_TRANSPORT/PTV_METRO_BUS_STOP.shp")
bus_sf
# Out:
#       STOP_ID                                          STOP_NAME   LATITUDE  \
# 0       10185       Bonnie View Rd/Maroondah Hwy (Croydon North) -37.780920
# 1       10186          Primrose Rd/Maroondah Hwy (Croydon North) -37.774626
# 2       10187            Exeter Rd/Maroondah Hwy (Croydon North) -37.770446
# 3       10188  Maroondah Golf Park/Maroondah Hwy (Chirnside P... -37.766346
# 4       10189    Old Melbourne Rd/Maroondah Hwy (Chirnside Park) -37.765276
# ...       ...                                                ...        ...
# 18554   47586               Bambara Ct/Wright St (Sunshine West) -37.794654
# 18555   47587                Booral Dr/Wright St (Sunshine West) -37.794911
# 18556   47588             Fairbairn Rd/Wright St (Sunshine West) -37.794707
# 18557   47589               Dalpura Dr/Wright St (Sunshine West) -37.794700
# 18558    4759           Moonee Ponds PS/Wilson St (Moonee Ponds) -37.763414
#
# ...

# %%
train_sf = gpd.read_file("../data/raw/PUBLIC_TRANSPORT/PTV_METRO_TRAIN_STATION.shp")
train_sf
# Out:
#     STOP_ID                                          STOP_NAME   LATITUDE  \
# 0     19970             Royal Park Railway Station (Parkville) -37.781193
# 1     19971  Flemington Bridge Railway Station (North Melbo... -37.788140
# 2     19972         Macaulay Railway Station (North Melbourne) -37.794267
# 3     19973   North Melbourne Railway Station (West Melbourne) -37.807419
# 4     19974        Clifton Hill Railway Station (Clifton Hill) -37.788657
# ..      ...                                                ...        ...
# 215   19965                    Coburg Railway Station (Coburg) -37.742345
# 216   19966                  Moreland Railway Station (Coburg) -37.754485
# 217   19967                 Anstey Railway Station (Brunswick) -37.761242
# 218   19968              Brunswick Railway Station (Brunswick) -37.767721
# 219   19969                 Jewell Railway Station (Brunswick) -37.774987
#
#       LONGITUDE TICKETZONE                                          ROUTEUSSP  \
# ...

# %%
tram_sf = gpd.read_file("../data/raw/PUBLIC_TRANSPORT/PTV_METRO_TRAM_STOP.shp")
tram_sf
# Out:
#      STOP_ID                                   STOP_NAME   LATITUDE  \
# 0      18730     134-Merribell Ave/Nicholson St (Coburg) -37.744359
# 1      18732     44-Deepdene Park/Whitehorse Rd (Balwyn) -37.811375
# 2      18733      45-Hardwicke St/Whitehorse Rd (Balwyn) -37.811750
# 3      18734     46-Balwyn Cinema/Whitehorse Rd (Balwyn) -37.812242
# 4      18735         47-Balwyn Rd/Whitehorse Rd (Balwyn) -37.812919
# ...      ...                                         ...        ...
# 1660    6037              34-Bent St/High St (Northcote) -37.767614
# 1661    6038         33-Arthurton Rd/High St (Northcote) -37.769413
# 1662    6039          32-Mitchell St/High St (Northcote) -37.771138
# 1663    6040  31-Northcote Town Hall/High St (Northcote) -37.774712
# 1664    6041            30-Clarke St/High St (Northcote) -37.776690
#
#        LONGITUDE TICKETZONE ROUTEUSSP                     geometry
# 0     144.977728          1         1  POINT (144.97773 -37.74435)
# ...

# %%
region_bus_sf = gpd.read_file("../data/raw/PUBLIC_TRANSPORT/PTV_REGIONAL_BUS_STOP.shp")
region_bus_sf
# Out:
#      STOP_ID                                          STOP_NAME   LATITUDE  \
# 0      23195                       Andrew St/Union St (Kilmore) -37.290492
# 1      23197             Wellington Square SC/Queen St (Wallan) -37.412990
# 2      23202              Aquamoves/Tom Collins Dr (Shepparton) -36.386027
# 3      23224  West End Caravan Park/Murray Valley Hwy (Yarra... -36.022176
# 4      23225                      Jane Rd/Fiona Dr (Yarrawonga) -36.006707
# ...      ...                                                ...        ...
# 6738     536                  Memorial Dr/Sago Hill Rd (Haddon) -37.589701
# 6739    6285                     Bloomfield Rd/Queen St (Nilma) -38.169784
# 6740      63           Armstrong St/Sturt St (Ballarat Central) -37.561515
# 6741    7009                 Harrison St/Marengo Crst (Marengo) -38.777123
# 6742      82  Ballarat Railway Station/Lydiard St (Ballarat ... -37.558656
#
#        LONGITUDE  ROUTEUSSP                     geometry
# ...

# %%
region_coach_sf = gpd.read_file("../data/raw/PUBLIC_TRANSPORT/PTV_REGIONAL_COACH_STOP.shp")
region_coach_sf
# Out:
#     STOP_ID                                       STOP_NAME   LATITUDE  \
# 0     18676     Euroa - Mansfield Rd/Maroondah Hwy (Merton) -36.977321
# 1     18677       Euroa-Mansfield Rd/Maroondah Hwy (Merton) -36.977598
# 2     18678           Woolshed Rd/Maroondah Hwy (Woodfield) -37.022249
# 3     18679           Woolshed Rd/Maroondah Hwy (Woodfield) -37.022554
# 4     18680               Phillip St/Bon Cres (Bonnie Doon) -37.026551
# ..      ...                                             ...        ...
# 796   18671                east of Pechell St/High St (Yea) -37.211162
# 797   18672  General Store/Goulburn Valley Hwy (Molesworth) -37.167309
# 798   18673  General Store/Goulburn Valley Hwy (Molesworth) -37.167347
# 799   18674                Wrights St/Maroondah Hwy (Yarck) -37.101185
# 800   18675                Wrights St/Maroondah Hwy (Yarck) -37.101287
#
#       LONGITUDE                     geometry
# 0    145.710830  POINT (145.71084 -36.97731)
# ...

# %%
region_train_sf = gpd.read_file("../data/raw/PUBLIC_TRANSPORT/PTV_REGIONAL_TRAIN_STATION.shp")
region_train_sf
# Out:
#     STOP_ID                                     STOP_NAME   LATITUDE  \
# 0     17204               Wallan Railway Station (Wallan) -37.416861
# 1     19980         Melton Railway Station (Melton South) -37.703359
# 2     19981           Rockbank Railway Station (Rockbank) -37.729261
# 3     19982         Deer Park Railway Station (Deer Park) -37.777764
# 4     19998             Sunbury Railway Station (Sunbury) -37.579206
# ..      ...                                           ...        ...
# 105   47642                 Epsom Railway Station (Epsom) -36.706342
# 106   47647    Wyndham Vale Railway Station (Manor Lakes) -37.872886
# 107   47648             Tarneit Railway Station (Tarneit) -37.832168
# 108   48804       Cobblebank Railway Station (Cobblebank) -37.712546
# 109   52011  Caroline Springs Railway Station (Ravenhall) -37.766145
#
#       LONGITUDE                     geometry
# 0    145.005372  POINT (145.00538 -37.41685)
# 1    144.572216  POINT (144.57222 -37.70335)
# ...

# %%
skybus_sf = gpd.read_file("../data/raw/PUBLIC_TRANSPORT/PTV_SKYBUS_STOP.shp")
skybus_sf
# Out:
#   STOP_ID                                          STOP_NAME   LATITUDE  \
# 0   23173  Skybus Coach Terminal/Spencer St (Melbourne City) -37.816045
# 1   23175  Skybus Coach Terminal/Spencer St (Melbourne City) -37.816551
# 2   45511  Melbourne Airport T1 Skybus/Arrival Dr (Melbou... -37.669331
# 3   45513  Melbourne Airport T3 Skybus/Arrival Dr (Melbou... -37.670936
#
#     LONGITUDE ROUTEUSSP                     geometry
# 0  144.951975      None  POINT (144.95198 -37.81603)
# 1  144.952586      None  POINT (144.95259 -37.81654)
# 2  144.850681      None  POINT (144.85069 -37.66932)
# 3  144.848741      None  POINT (144.84875 -37.67092)
